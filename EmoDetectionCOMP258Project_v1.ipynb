# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tensorflow import keras
from tensorflow.keras import layers
import os
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from keras.models import Sequential
from tensorflow.python.keras import backend as K

# %%
print(tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.11.0
# Num GPUs Available:  0

# %% [raw]
# Load Dataset

# %%
train_data = keras.utils.image_dataset_from_directory(
    directory = 'images/train',
    labels = 'inferred',
    label_mode = 'int',
    batch_size = 120,
    image_size = (48, 48)
)
# Out:
# Found 28709 files belonging to 7 classes.

# %%
validation_data = keras.utils.image_dataset_from_directory(
    directory = 'images/test',
    labels = 'inferred',
    label_mode = 'int',
    batch_size = 120,
    image_size = (48, 48)
)
# Out:
# Found 7178 files belonging to 7 classes.

# %% [raw]
# Data Exploration

# %%
def plot_distribution(dataset, title):
    labels = []
    for _, label in dataset.unbatch():
        labels.append(label.numpy())  # Append the scalar value
    
    unique, counts = np.unique(labels, return_counts=True)
    plt.bar(unique, counts, color='skyblue')
    plt.xlabel("Class Labels")
    plt.ylabel("Count")
    plt.title(title)
    plt.show()

# Plot initial class distribution
plot_distribution(train_data, "Class Distribution in Training Dataset")
plot_distribution(validation_data, "Class Distribution in Validation Dataset")
# Out:
# 2024-12-07 13:54:11.468207: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
def plot_images_by_class(dataset, class_names, num_images_per_class=5):
    """
    Plot a few sample images for each class from the dataset.
    
    :param dataset: The dataset to sample from.
    :param class_names: List of class names corresponding to labels.
    :param num_images_per_class: Number of images to display per class.
    """
    # Create a dictionary to store images for each class
    images_by_class = {class_label: [] for class_label in range(len(class_names))}

    for image, label in dataset.unbatch():
        label = label.numpy()
        if len(images_by_class[label]) < num_images_per_class:
            images_by_class[label].append(image.numpy())
        if all(len(images) == num_images_per_class for images in images_by_class.values()):
            break

    # Plot images with a smaller figure size
    fig, axs = plt.subplots(len(class_names), num_images_per_class, figsize=(10, 2 * len(class_names)))  # Reduced figsize
    fig.tight_layout()

    for class_label, images in images_by_class.items():
        for i, img in enumerate(images):
            ax = axs[class_label, i] if len(class_names) > 1 else axs[i]
            ax.imshow(img.astype("uint8"))
            ax.axis("off")
            if i == 0:
                ax.set_title(class_names[class_label])

    plt.show()

class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
plot_images_by_class(train_data, class_names)

# %% [raw]
# Data Preprocessing

# %%
def Normalize(image, label):
  image = tf.cast(image/255.0, tf.float32)
  return image,label

validate = validation_data.map(Normalize)

# %%
train_data = train_data.cache().shuffle(buffer_size=1000)

# %%
for images, labels in train_data.take(1):
    print(labels)
# Out:
# tf.Tensor(
# [0 3 4 0 4 4 4 0 3 3 5 6 0 3 5 3 3 5 6 2 3 0 0 6 2 6 4 3 3 5 3 5 0 3 2 6 6
#  5 2 3 2 3 3 6 0 5 3 3 5 3 3 5 2 4 2 3 3 3 3 4 2 2 6 3 2 3 3 4 2 0 5 6 2 6
#  3 0 6 3 6 4 0 0 5 5 2 4 2 3 0 3 2 6 0 3 6 2 4 4 3 2 6 6 0 4 5 0 2 4 3 3 5
#  5 0 3 4 5 2 4 3 3], shape=(120,), dtype=int32)

# %%
validation_data = validation_data.cache().shuffle(buffer_size=1000)

# %% [raw]
# CNN model training

# %%
num_classes = 7

# %%
import os.path
model_file = "my_model.keras"
'''
if os.path.isfile(model_file):
    print(f"Loaded existing model: {model_file}")
    model = tf.keras.models.load_model(model_file)
'''
model = Sequential()
model.add(tf.keras.layers.Rescaling(1./255, input_shape=(48, 48, 3)))
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2))) 
model.add(Dropout(0.5))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model.compile(optimizer = optimizer, loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 48, 48, 3)         0
#
#  conv2d (Conv2D)             (None, 46, 46, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 22, 22, 64)       0
#  )
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 64)        36928
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 6, 6, 128)         147584
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 256)         295168
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 880,199
# Trainable params: 880,199
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# define the checkpoint
filepath= "weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
history = model.fit(train_data, epochs=50, validation_data=validate, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 240/240 [==============================] - ETA: 0s - loss: 1.8381 - accuracy: 0.2440
# Epoch 1: loss improved from inf to 1.83812, saving model to weights-improvement-01-1.8381.hdf5
# 240/240 [==============================] - 73s 301ms/step - loss: 1.8381 - accuracy: 0.2440 - val_loss: 1.8964 - val_accuracy: 0.2471
# Epoch 2/50
# 240/240 [==============================] - ETA: 0s - loss: 1.8213 - accuracy: 0.2499
# Epoch 2: loss improved from 1.83812 to 1.82130, saving model to weights-improvement-02-1.8213.hdf5
# 240/240 [==============================] - 72s 298ms/step - loss: 1.8213 - accuracy: 0.2499 - val_loss: 1.8536 - val_accuracy: 0.2471
# Epoch 3/50
# 240/240 [==============================] - ETA: 0s - loss: 1.8163 - accuracy: 0.2505
# Epoch 3: loss improved from 1.82130 to 1.81632, saving model to weights-improvement-03-1.8163.hdf5
# 240/240 [==============================] - 76s 315ms/step - loss: 1.8163 - accuracy: 0.2505 - val_loss: 1.8177 - val_accuracy: 0.2471
# Epoch 4/50
# 240/240 [==============================] - ETA: 0s - loss: 1.7722 - accuracy: 0.2655
# Epoch 4: loss improved from 1.81632 to 1.77220, saving model to weights-improvement-04-1.7722.hdf5
# 240/240 [==============================] - 74s 307ms/step - loss: 1.7722 - accuracy: 0.2655 - val_loss: 1.8804 - val_accuracy: 0.1737
# Epoch 5/50
# 240/240 [==============================] - ETA: 0s - loss: 1.6569 - accuracy: 0.3369
# Epoch 5: loss improved from 1.77220 to 1.65692, saving model to weights-improvement-05-1.6569.hdf5
# 240/240 [==============================] - 72s 301ms/step - loss: 1.6569 - accuracy: 0.3369 - val_loss: 1.8807 - val_accuracy: 0.1737
# Epoch 6/50
# 240/240 [==============================] - ETA: 0s - loss: 1.5783 - accuracy: 0.3770
# Epoch 6: loss improved from 1.65692 to 1.57830, saving model to weights-improvement-06-1.5783.hdf5
# 240/240 [==============================] - 71s 296ms/step - loss: 1.5783 - accuracy: 0.3770 - val_loss: 1.8776 - val_accuracy: 0.1737
# Epoch 7/50
# 240/240 [==============================] - ETA: 0s - loss: 1.5196 - accuracy: 0.4043
# Epoch 7: loss improved from 1.57830 to 1.51964, saving model to weights-improvement-07-1.5196.hdf5
# 240/240 [==============================] - 72s 299ms/step - loss: 1.5196 - accuracy: 0.4043 - val_loss: 1.9282 - val_accuracy: 0.1737
# Epoch 8/50
# 240/240 [==============================] - ETA: 0s - loss: 1.4530 - accuracy: 0.4345
# Epoch 8: loss improved from 1.51964 to 1.45304, saving model to weights-improvement-08-1.4530.hdf5
# 240/240 [==============================] - 75s 311ms/step - loss: 1.4530 - accuracy: 0.4345 - val_loss: 1.8980 - val_accuracy: 0.1737
# Epoch 9/50
# 240/240 [==============================] - ETA: 0s - loss: 1.4072 - accuracy: 0.4616
# Epoch 9: loss improved from 1.45304 to 1.40720, saving model to weights-improvement-09-1.4072.hdf5
# 240/240 [==============================] - 72s 301ms/step - loss: 1.4072 - accuracy: 0.4616 - val_loss: 1.8946 - val_accuracy: 0.1737
# Epoch 10/50
# 240/240 [==============================] - ETA: 0s - loss: 1.3711 - accuracy: 0.4775
# Epoch 10: loss improved from 1.40720 to 1.37109, saving model to weights-improvement-10-1.3711.hdf5
# 240/240 [==============================] - 73s 304ms/step - loss: 1.3711 - accuracy: 0.4775 - val_loss: 1.9023 - val_accuracy: 0.1737
# Epoch 11/50
# 240/240 [==============================] - ETA: 0s - loss: 1.3430 - accuracy: 0.4879
# Epoch 11: loss improved from 1.37109 to 1.34301, saving model to weights-improvement-11-1.3430.hdf5
# 240/240 [==============================] - 71s 297ms/step - loss: 1.3430 - accuracy: 0.4879 - val_loss: 1.9377 - val_accuracy: 0.1737
# Epoch 12/50
# 240/240 [==============================] - ETA: 0s - loss: 1.3095 - accuracy: 0.5017
# Epoch 12: loss improved from 1.34301 to 1.30949, saving model to weights-improvement-12-1.3095.hdf5
# 240/240 [==============================] - 74s 308ms/step - loss: 1.3095 - accuracy: 0.5017 - val_loss: 1.8872 - val_accuracy: 0.1737
# Epoch 13/50
# 240/240 [==============================] - ETA: 0s - loss: 1.2913 - accuracy: 0.5104
# Epoch 13: loss improved from 1.30949 to 1.29129, saving model to weights-improvement-13-1.2913.hdf5
# 240/240 [==============================] - 76s 316ms/step - loss: 1.2913 - accuracy: 0.5104 - val_loss: 1.8897 - val_accuracy: 0.1737
# Epoch 14/50
# 240/240 [==============================] - ETA: 0s - loss: 1.2639 - accuracy: 0.5187
# Epoch 14: loss improved from 1.29129 to 1.26386, saving model to weights-improvement-14-1.2639.hdf5
# 240/240 [==============================] - 78s 326ms/step - loss: 1.2639 - accuracy: 0.5187 - val_loss: 1.8770 - val_accuracy: 0.1737
# Epoch 15/50
# 240/240 [==============================] - ETA: 0s - loss: 1.2473 - accuracy: 0.5271
# Epoch 15: loss improved from 1.26386 to 1.24727, saving model to weights-improvement-15-1.2473.hdf5
# 240/240 [==============================] - 83s 347ms/step - loss: 1.2473 - accuracy: 0.5271 - val_loss: 1.8863 - val_accuracy: 0.1737
# Epoch 16/50
# 240/240 [==============================] - ETA: 0s - loss: 1.2246 - accuracy: 0.5347
# Epoch 16: loss improved from 1.24727 to 1.22458, saving model to weights-improvement-16-1.2246.hdf5
# 240/240 [==============================] - 75s 312ms/step - loss: 1.2246 - accuracy: 0.5347 - val_loss: 1.9058 - val_accuracy: 0.1737
# Epoch 17/50
# 240/240 [==============================] - ETA: 0s - loss: 1.2077 - accuracy: 0.5402
# Epoch 17: loss improved from 1.22458 to 1.20769, saving model to weights-improvement-17-1.2077.hdf5
# 240/240 [==============================] - 72s 299ms/step - loss: 1.2077 - accuracy: 0.5402 - val_loss: 1.9026 - val_accuracy: 0.1737
# Epoch 18/50
# 240/240 [==============================] - ETA: 0s - loss: 1.1921 - accuracy: 0.5478
# Epoch 18: loss improved from 1.20769 to 1.19212, saving model to weights-improvement-18-1.1921.hdf5
# 240/240 [==============================] - 77s 321ms/step - loss: 1.1921 - accuracy: 0.5478 - val_loss: 1.9237 - val_accuracy: 0.1737
# Epoch 19/50
# 240/240 [==============================] - ETA: 0s - loss: 1.1742 - accuracy: 0.5568
# Epoch 19: loss improved from 1.19212 to 1.17421, saving model to weights-improvement-19-1.1742.hdf5
# 240/240 [==============================] - 71s 296ms/step - loss: 1.1742 - accuracy: 0.5568 - val_loss: 1.9042 - val_accuracy: 0.1737
# Epoch 20/50
# 240/240 [==============================] - ETA: 0s - loss: 1.1658 - accuracy: 0.5575
# Epoch 20: loss improved from 1.17421 to 1.16583, saving model to weights-improvement-20-1.1658.hdf5
# 240/240 [==============================] - 72s 298ms/step - loss: 1.1658 - accuracy: 0.5575 - val_loss: 1.9179 - val_accuracy: 0.1737
# Epoch 21/50
# 240/240 [==============================] - ETA: 0s - loss: 1.1473 - accuracy: 0.5671
# Epoch 21: loss improved from 1.16583 to 1.14733, saving model to weights-improvement-21-1.1473.hdf5
# 240/240 [==============================] - 71s 297ms/step - loss: 1.1473 - accuracy: 0.5671 - val_loss: 1.9825 - val_accuracy: 0.1737
# Epoch 22/50
# 240/240 [==============================] - ETA: 0s - loss: 1.1320 - accuracy: 0.5700
# Epoch 22: loss improved from 1.14733 to 1.13199, saving model to weights-improvement-22-1.1320.hdf5
# 240/240 [==============================] - 72s 298ms/step - loss: 1.1320 - accuracy: 0.5700 - val_loss: 1.9933 - val_accuracy: 0.1335
# Epoch 23/50
# 240/240 [==============================] - ETA: 0s - loss: 1.1151 - accuracy: 0.5788
# Epoch 23: loss improved from 1.13199 to 1.11513, saving model to weights-improvement-23-1.1151.hdf5
# 240/240 [==============================] - 72s 302ms/step - loss: 1.1151 - accuracy: 0.5788 - val_loss: 1.9820 - val_accuracy: 0.1335
# Epoch 24/50
# 240/240 [==============================] - ETA: 0s - loss: 1.1048 - accuracy: 0.5828
# Epoch 24: loss improved from 1.11513 to 1.10484, saving model to weights-improvement-24-1.1048.hdf5
# 240/240 [==============================] - 71s 297ms/step - loss: 1.1048 - accuracy: 0.5828 - val_loss: 1.9857 - val_accuracy: 0.1335
# Epoch 25/50
# 240/240 [==============================] - ETA: 0s - loss: 1.0996 - accuracy: 0.5833
# Epoch 25: loss improved from 1.10484 to 1.09960, saving model to weights-improvement-25-1.0996.hdf5
# 240/240 [==============================] - 72s 301ms/step - loss: 1.0996 - accuracy: 0.5833 - val_loss: 1.9789 - val_accuracy: 0.1737
# Epoch 26/50
# 240/240 [==============================] - ETA: 0s - loss: 1.0778 - accuracy: 0.5942
# Epoch 26: loss improved from 1.09960 to 1.07776, saving model to weights-improvement-26-1.0778.hdf5
# 240/240 [==============================] - 74s 310ms/step - loss: 1.0778 - accuracy: 0.5942 - val_loss: 1.9839 - val_accuracy: 0.1335
# Epoch 27/50
# 240/240 [==============================] - ETA: 0s - loss: 1.0720 - accuracy: 0.5917
# Epoch 27: loss improved from 1.07776 to 1.07195, saving model to weights-improvement-27-1.0720.hdf5
# 240/240 [==============================] - 73s 303ms/step - loss: 1.0720 - accuracy: 0.5917 - val_loss: 2.0225 - val_accuracy: 0.1335
# Epoch 28/50
# 240/240 [==============================] - ETA: 0s - loss: 1.0571 - accuracy: 0.5968
# Epoch 28: loss improved from 1.07195 to 1.05712, saving model to weights-improvement-28-1.0571.hdf5
# 240/240 [==============================] - 74s 308ms/step - loss: 1.0571 - accuracy: 0.5968 - val_loss: 2.0610 - val_accuracy: 0.1335
# Epoch 29/50
# 240/240 [==============================] - ETA: 0s - loss: 1.0450 - accuracy: 0.6062
# Epoch 29: loss improved from 1.05712 to 1.04504, saving model to weights-improvement-29-1.0450.hdf5
# 240/240 [==============================] - 75s 313ms/step - loss: 1.0450 - accuracy: 0.6062 - val_loss: 2.0511 - val_accuracy: 0.1335
# Epoch 30/50
# 240/240 [==============================] - ETA: 0s - loss: 1.0359 - accuracy: 0.6088
# Epoch 30: loss improved from 1.04504 to 1.03590, saving model to weights-improvement-30-1.0359.hdf5
# 240/240 [==============================] - 72s 300ms/step - loss: 1.0359 - accuracy: 0.6088 - val_loss: 1.9963 - val_accuracy: 0.1335
# Epoch 31/50
# 240/240 [==============================] - ETA: 0s - loss: 1.0257 - accuracy: 0.6137
# Epoch 31: loss improved from 1.03590 to 1.02566, saving model to weights-improvement-31-1.0257.hdf5
# 240/240 [==============================] - 73s 304ms/step - loss: 1.0257 - accuracy: 0.6137 - val_loss: 2.0149 - val_accuracy: 0.1335
# Epoch 32/50
# 240/240 [==============================] - ETA: 0s - loss: 1.0063 - accuracy: 0.6208
# Epoch 32: loss improved from 1.02566 to 1.00631, saving model to weights-improvement-32-1.0063.hdf5
# 240/240 [==============================] - 73s 306ms/step - loss: 1.0063 - accuracy: 0.6208 - val_loss: 1.9875 - val_accuracy: 0.1335
# Epoch 33/50
# 240/240 [==============================] - ETA: 0s - loss: 0.9995 - accuracy: 0.6244
# Epoch 33: loss improved from 1.00631 to 0.99949, saving model to weights-improvement-33-0.9995.hdf5
# 240/240 [==============================] - 73s 304ms/step - loss: 0.9995 - accuracy: 0.6244 - val_loss: 1.9897 - val_accuracy: 0.1335
# Epoch 34/50
# 240/240 [==============================] - ETA: 0s - loss: 0.9885 - accuracy: 0.6293
# Epoch 34: loss improved from 0.99949 to 0.98855, saving model to weights-improvement-34-0.9885.hdf5
# 240/240 [==============================] - 73s 303ms/step - loss: 0.9885 - accuracy: 0.6293 - val_loss: 2.0894 - val_accuracy: 0.1335
# Epoch 35/50
# 240/240 [==============================] - ETA: 0s - loss: 0.9802 - accuracy: 0.6346
# Epoch 35: loss improved from 0.98855 to 0.98016, saving model to weights-improvement-35-0.9802.hdf5
# 240/240 [==============================] - 75s 311ms/step - loss: 0.9802 - accuracy: 0.6346 - val_loss: 2.0358 - val_accuracy: 0.1335
# Epoch 36/50
# 240/240 [==============================] - ETA: 0s - loss: 0.9661 - accuracy: 0.6365
# Epoch 36: loss improved from 0.98016 to 0.96605, saving model to weights-improvement-36-0.9661.hdf5
# 240/240 [==============================] - 73s 304ms/step - loss: 0.9661 - accuracy: 0.6365 - val_loss: 2.0773 - val_accuracy: 0.1335
# Epoch 37/50
# 240/240 [==============================] - ETA: 0s - loss: 0.9617 - accuracy: 0.6389
# Epoch 37: loss improved from 0.96605 to 0.96169, saving model to weights-improvement-37-0.9617.hdf5
# 240/240 [==============================] - 74s 310ms/step - loss: 0.9617 - accuracy: 0.6389 - val_loss: 2.1728 - val_accuracy: 0.1335
# Epoch 38/50
# 240/240 [==============================] - ETA: 0s - loss: 0.9470 - accuracy: 0.6437
# Epoch 38: loss improved from 0.96169 to 0.94702, saving model to weights-improvement-38-0.9470.hdf5
# 240/240 [==============================] - 74s 307ms/step - loss: 0.9470 - accuracy: 0.6437 - val_loss: 2.1442 - val_accuracy: 0.1335
# Epoch 39/50
# 240/240 [==============================] - ETA: 0s - loss: 0.9335 - accuracy: 0.6502
# Epoch 39: loss improved from 0.94702 to 0.93351, saving model to weights-improvement-39-0.9335.hdf5
# 240/240 [==============================] - 72s 300ms/step - loss: 0.9335 - accuracy: 0.6502 - val_loss: 2.0750 - val_accuracy: 0.1335
# Epoch 40/50
# 240/240 [==============================] - ETA: 0s - loss: 0.9206 - accuracy: 0.6548
# Epoch 40: loss improved from 0.93351 to 0.92055, saving model to weights-improvement-40-0.9206.hdf5
# 240/240 [==============================] - 72s 299ms/step - loss: 0.9206 - accuracy: 0.6548 - val_loss: 2.0184 - val_accuracy: 0.1335
# Epoch 41/50
# 240/240 [==============================] - ETA: 0s - loss: 0.9047 - accuracy: 0.6617
# Epoch 41: loss improved from 0.92055 to 0.90466, saving model to weights-improvement-41-0.9047.hdf5
# 240/240 [==============================] - 72s 299ms/step - loss: 0.9047 - accuracy: 0.6617 - val_loss: 2.0943 - val_accuracy: 0.1335
# Epoch 42/50
# 240/240 [==============================] - ETA: 0s - loss: 0.8986 - accuracy: 0.6636
# Epoch 42: loss improved from 0.90466 to 0.89858, saving model to weights-improvement-42-0.8986.hdf5
# 240/240 [==============================] - 72s 299ms/step - loss: 0.8986 - accuracy: 0.6636 - val_loss: 2.0598 - val_accuracy: 0.1335
# Epoch 43/50
# 240/240 [==============================] - ETA: 0s - loss: 0.8870 - accuracy: 0.6661
# Epoch 43: loss improved from 0.89858 to 0.88698, saving model to weights-improvement-43-0.8870.hdf5
# 240/240 [==============================] - 73s 305ms/step - loss: 0.8870 - accuracy: 0.6661 - val_loss: 2.0755 - val_accuracy: 0.1335
# Epoch 44/50
# 240/240 [==============================] - ETA: 0s - loss: 0.8789 - accuracy: 0.6736
# Epoch 44: loss improved from 0.88698 to 0.87890, saving model to weights-improvement-44-0.8789.hdf5
# 240/240 [==============================] - 73s 304ms/step - loss: 0.8789 - accuracy: 0.6736 - val_loss: 1.9906 - val_accuracy: 0.1737
# Epoch 45/50
# 240/240 [==============================] - ETA: 0s - loss: 0.8641 - accuracy: 0.6776
# Epoch 45: loss improved from 0.87890 to 0.86414, saving model to weights-improvement-45-0.8641.hdf5
# 240/240 [==============================] - 73s 304ms/step - loss: 0.8641 - accuracy: 0.6776 - val_loss: 2.0354 - val_accuracy: 0.1335
# Epoch 46/50
# 240/240 [==============================] - ETA: 0s - loss: 0.8577 - accuracy: 0.6800
# Epoch 46: loss improved from 0.86414 to 0.85771, saving model to weights-improvement-46-0.8577.hdf5
# 240/240 [==============================] - 72s 301ms/step - loss: 0.8577 - accuracy: 0.6800 - val_loss: 2.0838 - val_accuracy: 0.1335
# Epoch 47/50
# 240/240 [==============================] - ETA: 0s - loss: 0.8422 - accuracy: 0.6842
# Epoch 47: loss improved from 0.85771 to 0.84218, saving model to weights-improvement-47-0.8422.hdf5
# 240/240 [==============================] - 72s 300ms/step - loss: 0.8422 - accuracy: 0.6842 - val_loss: 2.0462 - val_accuracy: 0.1335
# Epoch 48/50
# 240/240 [==============================] - ETA: 0s - loss: 0.8298 - accuracy: 0.6910
# Epoch 48: loss improved from 0.84218 to 0.82982, saving model to weights-improvement-48-0.8298.hdf5
# 240/240 [==============================] - 73s 303ms/step - loss: 0.8298 - accuracy: 0.6910 - val_loss: 2.0128 - val_accuracy: 0.1335
# Epoch 49/50
# 240/240 [==============================] - ETA: 0s - loss: 0.8242 - accuracy: 0.6896
# Epoch 49: loss improved from 0.82982 to 0.82418, saving model to weights-improvement-49-0.8242.hdf5
# 240/240 [==============================] - 75s 311ms/step - loss: 0.8242 - accuracy: 0.6896 - val_loss: 2.0958 - val_accuracy: 0.1335
# Epoch 50/50
# 240/240 [==============================] - ETA: 0s - loss: 0.8157 - accuracy: 0.6952
# Epoch 50: loss improved from 0.82418 to 0.81568, saving model to weights-improvement-50-0.8157.hdf5
# 240/240 [==============================] - 73s 303ms/step - loss: 0.8157 - accuracy: 0.6952 - val_loss: 2.0977 - val_accuracy: 0.1335

# %%
model.save(model_file)

# %%
plt.plot(history.history['accuracy'], color = 'red', label = 'train')
plt.plot(history.history['val_accuracy'], color = 'blue', label = 'validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], color = 'red', label = 'train')
plt.plot(history.history['val_loss'], color = 'blue', label = 'validation')
plt.legend()
plt.show()

# %%
# Evaluate model
loss, accuracy = model.evaluate(validate)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")
# Out:
# 60/60 [==============================] - 5s 81ms/step - loss: 2.0977 - accuracy: 0.1335
# Validation Accuracy: 13.35%
